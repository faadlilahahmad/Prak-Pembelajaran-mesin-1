# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/faadlilahahmad/Dataset/main/Indonesian%20Salary%20by%20Region%20(1997-2022).csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#            REGION  SALARY  YEAR
# 0            ACEH  128000  1997
# 1  SUMATERA UTARA  151000  1997
# 2  SUMATERA BARAT  119000  1997
# 3            RIAU  151500  1997
# 4           JAMBI  119500  1997

# %%
print(df.dtypes)
# Out:
# REGION    object
# SALARY     int64
# YEAR       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   REGION  870 non-null    object
#  1   SALARY  870 non-null    int64
#  2   YEAR    870 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 20.5+ KB

# %%
df.describe()
# Out:
#              SALARY         YEAR
# count  8.700000e+02   870.000000
# mean   1.179872e+06  2009.816092
# std    9.175435e+05     7.453930
# min    1.060000e+05  1997.000000
# 25%    4.215000e+05  2003.000000
# 50%    8.903875e+05  2010.000000
# 75%    1.867583e+06  2016.000000
# max    4.452724e+06  2022.000000

# %%
df.count()
# Out:
# REGION    870
# SALARY    870
# YEAR      870
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        REGION        SALARY         YEAR
# count     870  8.700000e+02   870.000000
# unique     35           NaN          NaN
# top      ACEH           NaN          NaN
# freq       26           NaN          NaN
# mean      NaN  1.179872e+06  2009.816092
# std       NaN  9.175435e+05     7.453930
# min       NaN  1.060000e+05  1997.000000
# 25%       NaN  4.215000e+05  2003.000000
# 50%       NaN  8.903875e+05  2010.000000
# 75%       NaN  1.867583e+06  2016.000000
# max       NaN  4.452724e+06  2022.000000

# %%
df.fillna(0)
# Out:
#              REGION   SALARY  YEAR
# 0              ACEH   128000  1997
# 1    SUMATERA UTARA   151000  1997
# 2    SUMATERA BARAT   119000  1997
# 3              RIAU   151500  1997
# 4             JAMBI   119500  1997
# ..              ...      ...   ...
# 865          MALUKU  2619312  2022
# 866    MALUKU UTARA  2862231  2022
# 867     PAPUA BARAT  3200000  2022
# 868           PAPUA  3561932  2022
# 869       INDONESIA  2644709  2022
#
# [870 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   REGION  870 non-null    object
#  1   SALARY  870 non-null    int64
#  2   YEAR    870 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 20.5+ KB

# %%
df['REGION'] = df['REGION'].fillna(0)
df['SALARY'] = df['SALARY'].fillna(0)
df['YEAR'] = df['YEAR'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   REGION  870 non-null    object
#  1   SALARY  870 non-null    int64
#  2   YEAR    870 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 20.5+ KB

# %%
df.describe(include='all')
# Out:
#        REGION        SALARY         YEAR
# count     870  8.700000e+02   870.000000
# unique     35           NaN          NaN
# top      ACEH           NaN          NaN
# freq       26           NaN          NaN
# mean      NaN  1.179872e+06  2009.816092
# std       NaN  9.175435e+05     7.453930
# min       NaN  1.060000e+05  1997.000000
# 25%       NaN  4.215000e+05  2003.000000
# 50%       NaN  8.903875e+05  2010.000000
# 75%       NaN  1.867583e+06  2016.000000
# max       NaN  4.452724e+06  2022.000000

# %%
df.corr()
# Out:
#           SALARY      YEAR
# SALARY  1.000000  0.914862
# YEAR    0.914862  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

korelasi = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(korelasi[(korelasi >= 0.5) | (korelasi <= -0.4)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1, 
            annot=True, annot_kws={"size": 8}, square=True).set_title('Korelasi Antar Variabel')
plt.show()

# %%
salarypercountry = df.groupby("REGION")["SALARY"].sum().sort_values()
salarypercountry.plot(kind="barh", fontsize=10, figsize=(8,40), title='Salary Tertinggi Per-region')
plt.show()

salaryperyear = df.groupby("YEAR")["SALARY"].sum().sort_values()
salaryperyear.plot(kind="barh", fontsize=10, figsize=(8,40), title='Salary Tertinggi Pertahun')
plt.show()

# %%
sns.boxplot(df['SALARY'])
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SALARY'>

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (20,20))
ax.scatter(df['SALARY'], df['REGION'])

# x-axis label
ax.set_xlabel('SALARY')
 
# y-axis label
ax.set_ylabel('REGION')
plt.show()

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\acer\anaconda3\lib\site-packages (1.0.1)

# %%
import nltk #import library nltk
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
from nltk.tokenize import sent_tokenize #import sent_tokenize for tokenizing paragraph into sentences
from nltk.stem.porter import PorterStemmer #import Porter Stemmer Algorithm 
from nltk.stem import WordNetLemmatizer #import WordNet lemmatizer 
from nltk.corpus import stopwords #import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
import re #import regular expression
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
#casefolding
def casefolding(s):
    new_str = s.lower()
    
    return new_str

text_data = "Saya suka belajar. Karena ingin menjadi pintar. Selain itu, saya ingin membuat bahagia kedua orang tua."
casefolding(text_data)
# Out:
# 'saya suka belajar. karena ingin menjadi pintar. selain itu, saya ingin membuat bahagia kedua orang tua.'

# %%
import nltk
nltk.download('punkt')

sent_tokenize(casefolding(text_data))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['saya suka belajar.',
#  'karena ingin menjadi pintar.',
#  'selain itu, saya ingin membuat bahagia kedua orang tua.']

# %%
#Stemming Indonesian
def stemmingIndo(str):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    return stemmer.stem(str)

stemmingIndo(text_data)
# Out:
# 'saya suka ajar karena ingin jadi pintar selain itu saya ingin buat bahagia dua orang tua'

# %%
#sentence tokenization
def sentence_tokenization(s):
    sentences_list = sent_tokenize(s)
    
    return sentences_list

sentence_tokenization(text_data)
# Out:
# ['Saya suka belajar.',
#  'Karena ingin menjadi pintar.',
#  'Selain itu, saya ingin membuat bahagia kedua orang tua.']

# %%
#word tokenization
def word_tokenization(s):
    tokens = word_tokenize(s)

    return tokens
    
word_tokenization(text_data)
# Out:
# ['Saya',
#  'suka',
#  'belajar',
#  '.',
#  'Karena',
#  'ingin',
#  'menjadi',
#  'pintar',
#  '.',
#  'Selain',
#  'itu',
#  ',',
#  'saya',
#  'ingin',
#  'membuat',
#  'bahagia',
#  'kedua',
#  'orang',
#  'tua',
#  '.']

# %%
word_tokenization(stemmingIndo(text_data))
# Out:
# ['saya',
#  'suka',
#  'ajar',
#  'karena',
#  'ingin',
#  'jadi',
#  'pintar',
#  'selain',
#  'itu',
#  'saya',
#  'ingin',
#  'buat',
#  'bahagia',
#  'dua',
#  'orang',
#  'tua']

# %%
#Stopwords removing
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
stopword.remove(text_data)
# Out:
# 'Saya suka belajar. Karena menjadi pintar. Selain itu, ingin membuat bahagia kedua orang tua.'

# %%
#Stemming English
def stemmingEnglish(str):
    porter_stemmer = PorterStemmer()
    words = word_tokenize(str)
    result = list()
    for word in words:
        result.append(porter_stemmer.stem(word))
        
    return ' '.join(result)

text_data = "She had been with her father and sister when she was attacked and received first aid at the scene, an official said."
stemmingEnglish(text_data)
# Out:
# 'she had been with her father and sister when she wa attack and receiv first aid at the scene , an offici said .'

# %%
porter_stemmer = PorterStemmer()

word_data = "It originated from the idea that there are readers who prefer learning new skills from the comforts of their drawing rooms"
# First Word tokenization
nltk_tokens = nltk.word_tokenize(word_data)
#Next find the roots of the word
for w in nltk_tokens:
       print("Actual: %s  Stem: %s"  % (w,porter_stemmer.stem(w)))
# Out:
# Actual: It  Stem: it
# Actual: originated  Stem: origin
# Actual: from  Stem: from
# Actual: the  Stem: the
# Actual: idea  Stem: idea
# Actual: that  Stem: that
# Actual: there  Stem: there
# Actual: are  Stem: are
# Actual: readers  Stem: reader
# Actual: who  Stem: who
# Actual: prefer  Stem: prefer
# Actual: learning  Stem: learn
# Actual: new  Stem: new
# Actual: skills  Stem: skill
# Actual: from  Stem: from
# Actual: the  Stem: the
# Actual: comforts  Stem: comfort
# Actual: of  Stem: of
# Actual: their  Stem: their
# Actual: drawing  Stem: draw
# Actual: rooms  Stem: room

# %%
#Lemmatization
nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()

word_data = "It originated from the idea that there are readers who prefer learning new skills from the comforts of their drawing rooms"
nltk_tokens = nltk.word_tokenize(word_data)
for w in nltk_tokens:
       print ("Actual: %s  Lemma: %s"  % (w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Actual: It  Lemma: It
# Actual: originated  Lemma: originated
# Actual: from  Lemma: from
# Actual: the  Lemma: the
# Actual: idea  Lemma: idea
# Actual: that  Lemma: that
# Actual: there  Lemma: there
# Actual: are  Lemma: are
# Actual: readers  Lemma: reader
# Actual: who  Lemma: who
# Actual: prefer  Lemma: prefer
# Actual: learning  Lemma: learning
# Actual: new  Lemma: new
# Actual: skills  Lemma: skill
# Actual: from  Lemma: from
# Actual: the  Lemma: the
# Actual: comforts  Lemma: comfort
# Actual: of  Lemma: of
# Actual: their  Lemma: their
# Actual: drawing  Lemma: drawing
# Actual: rooms  Lemma: room

# %%
#remove digit from string
def removeDigit(str):
    new_string =  re.sub(r"[0-9]", " ", str)
    return new_string

text_data = "Indonesia proklamasi tanggal 17 Agustus 1945 namun Belanda mengakui kedaulatan pada 27 Desember 1949"
removeDigit(text_data)
# Out:
# 'Indonesia proklamasi tanggal    Agustus      namun Belanda mengakui kedaulatan pada    Desember     '

# %%
#pos tagging
nltk.download('averaged_perceptron_tagger')
def postag(str):
    tok_sentence = nltk.word_tokenize(str)
    tagged_sentence = nltk.pos_tag(tok_sentence)
    return tagged_sentence

text_data = "It originated from the idea that there are readers who prefer learning new skills from the comforts of their drawing rooms"
postag(text_data)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('It', 'PRP'),
#  ('originated', 'VBD'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('idea', 'NN'),
#  ('that', 'IN'),
#  ('there', 'EX'),
#  ('are', 'VBP'),
#  ('readers', 'NNS'),
#  ('who', 'WP'),
#  ('prefer', 'VBP'),
#  ('learning', 'VBG'),
#  ('new', 'JJ'),
#  ('skills', 'NNS'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('comforts', 'NNS'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('drawing', 'NN'),
#  ('rooms', 'NNS')]

# %%
import re, string, unicodedata

def cleaning(str):
    #remove non-ascii
    str = unicodedata.normalize('NFKD', str).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    #remove URLs
    str = re.sub(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))', '', str)
    #remove punctuations
    str = re.sub(r'[^\w]|_',' ',str)
    #remove digit from string
    str = re.sub("\S*\d\S*", "", str).strip()
    #remove digit or numbers
    str = re.sub(r"\b\d+\b", " ", str)
    #to lowercase
    str = str.lower()
    #Remove additional white spaces
    str = re.sub('[\s]+', ' ', str)
    
    return str

str = "Copyright © 2008 John Wiley & Sons, Ltd. adalah ini https://www.analyticsvidhya.com/blog/2015/10/6-practices-enhance-performance-text-classification-model/"
print(cleaning(str))
# Out:
# copyright john wiley sons ltd adalah ini

# %%
import base64
import requests

url = 'https://raw.githubusercontent.com/faadlilahahmad/Dataset/main/quiz1.txt'
txt = requests.get(url)
txt = txt.text
print(txt)
# Out:
# 1. Jelaskan pemahaman Anda tentang pembelajaran mesin!
# Jawaban :
# Dari sumber-sumber yang saya pelajari, saya memiliki kesimpulan bahwa pembelajaran mesin adalah tingkat lanjut dari kecerdasan buatan, dimana mesin memiliki kemampuan untuk bisa belajar dengan sendirinya tanpa adanya campur tangan dari manusia.
# Sebenarnya dalam kehidupan sehari-hari kita sudah sering menemui bahkan menggunakan pembelajaran mesin, apalagi untuk zaman sekarang. Contoh pembelajaran mesin yang paling sering kita temui sehari-hari adalah mesin pencari Google. Jika kita mengetik sesuatu di kolom search Google, maka Google akan memunculkan rekomendasi dari hal yang sedang kita cari. Jika Google kita sedang Log-in, maka Google juga akan menampilkan hasil pencarian yang pernah kita cari. Contoh lainnya adalah pengenal wajah seseorang yang dapat kita temui di smartphone dan CCTV.
#
# 2. Jelaskan pemahaman Anda tentang perbedaan supervised, unsupervised, semi-supervised, dan reinforcement learning!
# Jawaban :
# 	Supervised Learning adalah jenis learning atau pembelajaran yang memiliki variable input dan variable output dengan menggunakan suatu algoritma dalam rangka mempelajari fungsi pemetaan dari input ke output untuk mendapatkan output yang dinginkan.
# 	Perbedaan mendasar supervised learning dengan unsupervised learning adalah unsupervised learning hanya mempunyai variable input (input data) tetapi tidak ada variabel output yang sesuai. Tujuannya adalah untuk mempelajari data lebih jauh lagi dan menyimpulkan fungsi yang mendeskripsikan atau menjelaskan data.
# 	Semi-supervised adalah adalah kombinasi dari supervised learning dan unsupervised learning dimana hanya beberapa output data yang yang diberi label. Contoh sederhananya adalah seperti arsip foto di mana hanya beberapa gambar yang diberi label, (misalnya kucing, anjing, manusia) dan sebagian besar tidak diberi label.
# 	Reinforcement learning adalah tipe learning yang bisa membuat software dan mesin bekerja secara otomatis dalam menentukan perilaku yang ideal terhadap sebuah konteks yang spesifik secara otomatis, dengan tujuan untuk memaksimalkan performanya.
#
# 3. Berikan contoh studi kasus yang dapat diselesaikan dengan pembelajaran mesin, lalu metode pembelajaran mesin apa yang bisa Anda gunakan? Mengapa menggunakan metode tersebut?
# Jawaban :
# 	Contoh studi kasusnya adalah Speech Emotion Recognition atau mengenali emosi seseorang melalui suara. Speech Emotion Recognition akan mencoba mengenali emosi seseorang melalui suara dengan memanfaatkan fakta bahwa suara sering kali mencerminkan emosi seseorang melalui nada dan tinggi nada. Ini juga merupakan fenomena yang digunakan hewan seperti anjing untuk memahami emosi manusia.
# 	Metode pembelajaran mesin yang digunakan adalah supervised learning. Mengapa? Karena setiap keluaran atau output telah diprediksi atau diberi label seperi senang, marah, sedih dan seterusnya.

# %%
clean_txt = cleaning(txt)

# %%
print(clean_txt)
# Out:
# jelaskan pemahaman anda tentang pembelajaran mesin jawaban dari sumber sumber yang saya pelajari saya memiliki kesimpulan bahwa pembelajaran mesin adalah tingkat lanjut dari kecerdasan buatan dimana mesin memiliki kemampuan untuk bisa belajar dengan sendirinya tanpa adanya campur tangan dari manusia sebenarnya dalam kehidupan sehari hari kita sudah sering menemui bahkan menggunakan pembelajaran mesin apalagi untuk zaman sekarang contoh pembelajaran mesin yang paling sering kita temui sehari hari adalah mesin pencari google jika kita mengetik sesuatu di kolom search google maka google akan memunculkan rekomendasi dari hal yang sedang kita cari jika google kita sedang log in maka google juga akan menampilkan hasil pencarian yang pernah kita cari contoh lainnya adalah pengenal wajah seseorang yang dapat kita temui di smartphone dan cctv jelaskan pemahaman anda tentang perbedaan supervised unsupervised semi supervised dan reinforcement learning jawaban supervised learning adalah jenis learning atau pembelajaran yang memiliki variable input dan variable output dengan menggunakan suatu algoritma dalam rangka mempelajari fungsi pemetaan dari input ke output untuk mendapatkan output yang dinginkan perbedaan mendasar supervised learning dengan unsupervised learning adalah unsupervised learning hanya mempunyai variable input input data tetapi tidak ada variabel output yang sesuai tujuannya adalah untuk mempelajari data lebih jauh lagi dan menyimpulkan fungsi yang mendeskripsikan atau menjelaskan data semi supervised adalah adalah kombinasi dari supervised learning dan unsupervised learning dimana hanya beberapa output data yang yang diberi label contoh sederhananya adalah seperti arsip foto di mana hanya beberapa gambar yang diberi label misalnya kucing anjing manusia dan sebagian besar tidak diberi label reinforcement learning adalah tipe learning yang bisa membuat software dan mesin bekerja secara otomatis dalam menentukan perilaku yang ideal terhadap sebuah konteks yang spesifik secara otomatis dengan tujuan untuk memaksimalkan performanya berikan contoh studi kasus yang dapat diselesaikan dengan pembelajaran mesin lalu metode pembelajaran mesin apa yang bisa anda gunakan mengapa menggunakan metode tersebut jawaban contoh studi kasusnya adalah speech emotion recognition atau mengenali emosi seseorang melalui suara speech emotion recognition akan mencoba mengenali emosi seseorang melalui suara dengan memanfaatkan fakta bahwa suara sering kali mencerminkan emosi seseorang melalui nada dan tinggi nada ini juga merupakan fenomena yang digunakan hewan seperti anjing untuk memahami emosi manusia metode pembelajaran mesin yang digunakan adalah supervised learning mengapa karena setiap keluaran atau output telah diprediksi atau diberi label seperi senang marah sedih dan seterusnya

# %%
stop = stopword.remove(clean_txt)
print(stop)
# Out:
# jelaskan pemahaman tentang pembelajaran mesin jawaban sumber sumber pelajari saya memiliki kesimpulan pembelajaran mesin tingkat lanjut kecerdasan buatan mesin memiliki kemampuan bisa belajar sendirinya adanya campur tangan manusia sebenarnya kehidupan sehari hari sudah sering menemui bahkan menggunakan pembelajaran mesin zaman sekarang contoh pembelajaran mesin paling sering temui sehari hari mesin pencari google mengetik kolom search google google memunculkan rekomendasi hal sedang cari google sedang log in google menampilkan hasil pencarian pernah cari contoh lainnya pengenal wajah seseorang dapat kita temui smartphone cctv jelaskan pemahaman tentang perbedaan supervised unsupervised semi supervised reinforcement learning jawaban supervised learning jenis learning pembelajaran memiliki variable input variable output menggunakan suatu algoritma rangka mempelajari fungsi pemetaan input output mendapatkan output dinginkan perbedaan mendasar supervised learning unsupervised learning unsupervised learning mempunyai variable input input data variabel output sesuai tujuannya mempelajari data lebih jauh menyimpulkan fungsi mendeskripsikan menjelaskan data semi supervised kombinasi supervised learning unsupervised learning beberapa output data diberi label contoh sederhananya arsip foto di mana hanya beberapa gambar diberi label misalnya kucing anjing manusia sebagian besar tidak diberi label reinforcement learning tipe learning bisa membuat software mesin bekerja otomatis menentukan perilaku ideal sebuah konteks spesifik otomatis tujuan untuk memaksimalkan performanya berikan contoh studi kasus dapat diselesaikan pembelajaran mesin lalu metode pembelajaran mesin apa bisa gunakan menggunakan metode tersebut jawaban contoh studi kasusnya speech emotion recognition mengenali emosi seseorang melalui suara speech emotion recognition akan mencoba mengenali emosi seseorang melalui suara memanfaatkan fakta suara sering kali mencerminkan emosi seseorang melalui nada tinggi nada juga merupakan fenomena digunakan hewan seperti anjing untuk memahami emosi manusia metode pembelajaran mesin yang digunakan adalah supervised learning karena keluaran output diprediksi diberi label seperi senang marah sedih dan seterusnya

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_font_size=30, background_color="white").generate(stop)
plt.figure(figsize=(10,8))

#plot wordcloud in matplotlib

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
words_in_article = stop.split()

print(words_in_article)
# Out:
# ['jelaskan', 'pemahaman', 'tentang', 'pembelajaran', 'mesin', 'jawaban', 'sumber', 'sumber', 'pelajari', 'saya', 'memiliki', 'kesimpulan', 'pembelajaran', 'mesin', 'tingkat', 'lanjut', 'kecerdasan', 'buatan', 'mesin', 'memiliki', 'kemampuan', 'bisa', 'belajar', 'sendirinya', 'adanya', 'campur', 'tangan', 'manusia', 'sebenarnya', 'kehidupan', 'sehari', 'hari', 'sudah', 'sering', 'menemui', 'bahkan', 'menggunakan', 'pembelajaran', 'mesin', 'zaman', 'sekarang', 'contoh', 'pembelajaran', 'mesin', 'paling', 'sering', 'temui', 'sehari', 'hari', 'mesin', 'pencari', 'google', 'mengetik', 'kolom', 'search', 'google', 'google', 'memunculkan', 'rekomendasi', 'hal', 'sedang', 'cari', 'google', 'sedang', 'log', 'in', 'google', 'menampilkan', 'hasil', 'pencarian', 'pernah', 'cari', 'contoh', 'lainnya', 'pengenal', 'wajah', 'seseorang', 'dapat', 'kita', 'temui', 'smartphone', 'cctv', 'jelaskan', 'pemahaman', 'tentang', 'perbedaan', 'supervised', 'unsupervised', 'semi', 'supervised', 'reinforcement', 'learning', 'jawaban', 'supervised', 'learning', 'jenis', 'learning', 'pembelajaran', 'memiliki', 'variable', 'input', 'variable', 'output', 'menggunakan', 'suatu', 'algoritma', 'rangka', 'mempelajari', 'fungsi', 'pemetaan', 'input', 'output', 'mendapatkan', 'output', 'dinginkan', 'perbedaan', 'mendasar', 'supervised', 'learning', 'unsupervised', 'learning', 'unsupervised', 'learning', 'mempunyai', 'variable', 'input', 'input', 'data', 'variabel', 'output', 'sesuai', 'tujuannya', 'mempelajari', 'data', 'lebih', 'jauh', 'menyimpulkan', 'fungsi', 'mendeskripsikan', 'menjelaskan', 'data', 'semi', 'supervised', 'kombinasi', 'supervised', 'learning', 'unsupervised', 'learning', 'beberapa', 'output', 'data', 'diberi', 'label', 'contoh', 'sederhananya', 'arsip', 'foto', 'di', 'mana', 'hanya', 'beberapa', 'gambar', 'diberi', 'label', 'misalnya', 'kucing', 'anjing', 'manusia', 'sebagian', 'besar', 'tidak', 'diberi', 'label', 'reinforcement', 'learning', 'tipe', 'learning', 'bisa', 'membuat', 'software', 'mesin', 'bekerja', 'otomatis', 'menentukan', 'perilaku', 'ideal', 'sebuah', 'konteks', 'spesifik', 'otomatis', 'tujuan', 'untuk', 'memaksimalkan', 'performanya', 'berikan', 'contoh', 'studi', 'kasus', 'dapat', 'diselesaikan', 'pembelajaran', 'mesin', 'lalu', 'metode', 'pembelajaran', 'mesin', 'apa', 'bisa', 'gunakan', 'menggunakan', 'metode', 'tersebut', 'jawaban', 'contoh', 'studi', 'kasusnya', 'speech', 'emotion', 'recognition', 'mengenali', 'emosi', 'seseorang', 'melalui', 'suara', 'speech', 'emotion', 'recognition', 'akan', 'mencoba', 'mengenali', 'emosi', 'seseorang', 'melalui', 'suara', 'memanfaatkan', 'fakta', 'suara', 'sering', 'kali', 'mencerminkan', 'emosi', 'seseorang', 'melalui', 'nada', 'tinggi', 'nada', 'juga', 'merupakan', 'fenomena', 'digunakan', 'hewan', 'seperti', 'anjing', 'untuk', 'memahami', 'emosi', 'manusia', 'metode', 'pembelajaran', 'mesin', 'yang', 'digunakan', 'adalah', 'supervised', 'learning', 'karena', 'keluaran', 'output', 'diprediksi', 'diberi', 'label', 'seperi', 'senang', 'marah', 'sedih', 'dan', 'seterusnya']

# %%
import collections
import itertools

# Create counter
counts_no_urls = collections.Counter(words_in_article)

counts_no_urls.most_common(5)
# Out:
# [('learning', 11),
#  ('mesin', 10),
#  ('pembelajaran', 8),
#  ('supervised', 7),
#  ('output', 6)]

# %%
df_txt = pd.DataFrame(counts_no_urls.most_common(15), columns=['words', 'count'])
df_txt.head()
# Out:
#           words  count
# 0      learning     11
# 1         mesin     10
# 2  pembelajaran      8
# 3    supervised      7
# 4        output      6

# %%
fig, ax = plt.subplots(figsize=(5, 5))

# Plot horizontal bar graph
df_txt.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="grey")

ax.set_title("Kata yang sering banyak muncul dari artikel Indonesia Tangguh Lawan Covid")

plt.show()
